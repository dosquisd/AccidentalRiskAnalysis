# %%
import seaborn as sns
import matplotlib.pyplot as plt

import os
import sys

parent_dir = os.path.abspath("..")
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

from utils.load_data import resample_data  # noqa: E402
from utils.constants import FIGURES_DIR  # noqa: E402
from utils.configure_scienceplots import configure_scienceplots  # noqa: E402

PAIRPLOT_FIGURES_DIR = FIGURES_DIR / "pairplots"
PAIRPLOT_FIGURES_DIR.mkdir(parents=True, exist_ok=True)

# %%
configure_scienceplots()

# %%
df = resample_data(freq="1W", multi_index=True)

# %%
sns.pairplot(df[["GRAVEDAD", "CLASE"]], diag_kind="kde", markers="+", plot_kws={"alpha": 1})
plt.savefig(PAIRPLOT_FIGURES_DIR / "pairplot_gravedad_clase.pdf", bbox_inches="tight")
plt.show()
